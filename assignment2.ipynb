# %%
student = {
    "name": "Nitin",
    "roll_no": 101,
    "branch": "CSE"
}

print("Student Details:")
print(student)

print("Name:", student["name"])

student["college"] = "SKIT Jaipur"

print("Updated Dictionary:")
print(student)
# Out:
# Student Details:
# {'name': 'Nitin', 'roll_no': 101, 'branch': 'CSE'}
# Name: Nitin
# Updated Dictionary:
# {'name': 'Nitin', 'roll_no': 101, 'branch': 'CSE', 'college': 'SKIT Jaipur'}

# %%
colors = ("Red", "Blue", "Green", "Black")

print("Tuple Elements:")
print(colors)

print("First Element:", colors[0])


print("Total Elements:", len(colors))
# Out:
# Tuple Elements:
# ('Red', 'Blue', 'Green', 'Black')
# First Element: Red
# Total Elements: 4

# %%
numbers = {1, 2, 3, 4, 5}

print("Original Set:")
print(numbers)

numbers.add(6)

print("Updated Set:")
print(numbers)
# Out:
# Original Set:
# {1, 2, 3, 4, 5}
# Updated Set:
# {1, 2, 3, 4, 5, 6}

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not possible"



num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))


print("Addition =", add(num1, num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", divide(num1, num2))
# Out:
# Addition = 30.0
# Subtraction = -10.0
# Multiplication = 200.0
# Division = 0.5

# %%
num = int(input("Enter a number: "))

original = num
reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10


if original == reverse:
    print(original, "is a Palindrome Number")
else:
    print(original, "is not a Palindrome Number")
# Out:
# 98789 is a Palindrome Number
