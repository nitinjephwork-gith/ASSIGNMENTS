# %%
name = "Nitin"
age = 20
print("Name:", name, "Age:", age)


print("Python", "Java", "C++", sep=" | ")


print("Hello", end=" ")
print("World")
# Out:
# Name: Nitin Age: 20
# Python | Java | C++
# Hello World

# %%
name = input("Enter your name: ")

print("Hello,", name + "! Welcome to Python Programming.")
# Out:
# Hello, nitin! Welcome to Python Programming.
