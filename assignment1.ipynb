# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

m1 = float(input("Enter marks of Subject 1: "))
m2 = float(input("Enter marks of Subject 2: "))
m3 = float(input("Enter marks of Subject 3: "))
m4 = float(input("Enter marks of Subject 4: "))
m5 = float(input("Enter marks of Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
# Out:
# ----- RESULT -----
# Student Name : nitin
# Class : 12
# Total Marks : 412.0
# Percentage : 82.4 %

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

result = str1 + " " + str2

print("\nConcatenated String:", result)


print("Lower Case:", result.lower())
print("Upper Case:", result.upper())
print("Title Case:", result.title())
print("Swap Case:", result.swapcase())
print("Capitalize:", result.capitalize())
print("Casefold:", result.casefold())

print("Centered String:", result.center(50, '*'))

print("Count of letter 'a':", result.count('a'))

print("Ends with 'a':", result.endswith('a'))

print("Find 'a':", result.find('a'))

print("Is Alphanumeric:", result.isalnum())

print("Is Digit:", result.isdigit())

print("Is Numeric:", result.isnumeric())

print("Is Space:", result.isspace())

print("Replace:", result.replace("a", "@"))
# Out:
# Concatenated String: this is a python program first assignment
# Lower Case: this is a python program first assignment
# Upper Case: THIS IS A PYTHON PROGRAM FIRST ASSIGNMENT
# Title Case: This Is A Python Program First Assignment
# Swap Case: THIS IS A PYTHON PROGRAM FIRST ASSIGNMENT
# Capitalize: This is a python program first assignment
# Casefold: this is a python program first assignment
# Centered String: ****this is a python program first assignment*****
# Count of letter 'a': 3
# Ends with 'a': False
# Find 'a': 8
# Is Alphanumeric: False
# Is Digit: False
# Is Numeric: False
# Is Space: False
# Replace: this is @ python progr@m first @ssignment

# %%
a = 10
b = 5

print("Initial value of a =", a)

a += b
print("After += :", a)

a -= b
print("After -= :", a)

a *= b
print("After *= :", a)

a /= b
print("After /= :", a)

a %= b
print("After %= :", a)

a **= 2
print("After **= :", a)

a //= 2
print("After //= :", a)
# Out:
# Initial value of a = 10
# After += : 15
# After -= : 10
# After *= : 50
# After /= : 10.0
# After %= : 0.0
# After **= : 0.0
# After //= : 0.0

# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

m1 = float(input("Enter marks of Subject 1: "))
m2 = float(input("Enter marks of Subject 2: "))
m3 = float(input("Enter marks of Subject 3: "))
m4 = float(input("Enter marks of Subject 4: "))
m5 = float(input("Enter marks of Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

if percentage >= 60:
    grade = 'A'

elif percentage >= 50 and percentage < 60:
    grade = 'B'

elif percentage >= 40 and percentage < 50:
    grade = 'C'

elif percentage >= 33 and percentage < 40:
    grade = 'D'

else:
    grade = 'Fail'


print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
print("Grade :", grade)
# Out:
# ----- RESULT -----
# Student Name : nitin jeph
# Class : 12
# Total Marks : 396.0
# Percentage : 79.2 %
# Grade : A
